# %% [markdown]
# <a href="https://colab.research.google.com/github/BinukOS/AKC-Projects/blob/main/Converting_Currencies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def convert_currency(tocurrency,amount):
  currency_rate = [147.5,0.74,80.19, 53.87,0.53, 2.63,4.75, 286, 100, ] #LKR, USD, Yen, RUB, GBP, DOGE, CNY, ROBUX
  converted_amount = 0
  if tocurrency == 'LKR':
    converted_amount = amount * currency_rate[0]

  elif tocurrency == 'USD':
    converted_amount = amount * currency_rate[1]

  elif tocurrency == 'YEN':
    converted_amount = amount * currency_rate[2]

  elif tocurrency == 'RUB':
    converted_amount = amount * currency_rate[3]

  elif tocurrency == 'GDP':
    converted_amount = amount * currency_rate[4]

  elif tocurrency == 'DOGE':
    converted_amount = amount * currency_rate[5]

  elif tocurrency == 'CNY':
    converted_amount = amount * currency_rate[6]

  elif tocurrency == 'ROBUX':
    converted_amount = amount * currency_rate[7]

  elif tocurrency == 'VBUX':
    converted_amount = amount * currency_rate[8]

  elif tocurrency == 'Give me free money':
    print("No")

  return converted_amount


tocurrency = input("What currency are you converting to? ")

amount = input("How much are you converting? ")
amount = float(amount)


newamount = convert_currency(tocurrency,amount)
print(newamount)
# Out:
# What currency are you converting to? Give me free money
# How much are you converting? 2
# No
# 0

# %%
def convert_currency(fromcurrency,amount):
  currency_rate = [147.5,0.74,80.19, 53.87,0.53, 2.63,4.75, 286, 100, ] #LKR, USD, Yen, RUB, GBP, DOGE, CNY, ROBUX
  converted_amount = 0
  if fromcurrency == 'LKR':
    converted_amount = amount / currency_rate[0]

  elif fromcurrency == 'USD':
    converted_amount = amount / currency_rate[1]

  elif fromcurrency == 'YEN':
    converted_amount = amount / currency_rate[2]

  elif fromcurrency == 'RUB':
    converted_amount = amount / currency_rate[3]

  elif fromcurrency == 'GDP':
    converted_amount = amount / currency_rate[4]

  elif fromcurrency == 'DOGE':
    converted_amount = amount / currency_rate[5]

  elif fromcurrency == 'CNY':
    converted_amount = amount / currency_rate[6]

  elif fromcurrency == 'ROBUX':
    converted_amount = amount / currency_rate[7]

  elif fromcurrency == 'VBUX':
    converted_amount = amount / currency_rate[8]

  elif fromcurrency == 'Give me free money':
    print("No")

  return converted_amount


fromcurrency = input("What currency are you converting from? ")

amount = input("How much are you converting? ")
amount = float(amount)


newamount = convert_currency(fromcurrency,amount)
print(newamount)

# %%
def convert_currency(fromcurrency,amount):
  currency_rate = [147.5,0.74,80.19, 53.87,0.53, 2.63,4.75, 286, 100, ] #LKR, USD, Yen, RUB, GBP, DOGE, CNY, ROBUX
  converted_amount = 0
  if fromcurrency == 'LKR':
    converted_amount = amount / currency_rate[0]

  elif fromcurrency == 'USD':
    converted_amount = amount / currency_rate[1]

  elif fromcurrency == 'YEN':
    converted_amount = amount / currency_rate[2]

  elif fromcurrency == 'RUB':
    converted_amount = amount / currency_rate[3]

  elif fromcurrency == 'GDP':
    converted_amount = amount / currency_rate[4]

  elif fromcurrency == 'DOGE':
    converted_amount = amount / currency_rate[5]

  elif fromcurrency == 'CNY':
    converted_amount = amount / currency_rate[6]

  elif fromcurrency == 'ROBUX':
    converted_amount = amount / currency_rate[7]

  elif fromcurrency == 'VBUX':
    converted_amount = amount / currency_rate[8]

  elif fromcurrency == 'Give me free money':
     print("No")

  return converted_amount

def conver_currency(tocurrency,amount):
  currency_rate = [147.5,0.74,80.19, 53.87,0.53, 2.63,4.75, 286, 100, ] #LKR, USD, Yen, RUB, GBP, DOGE, CNY, ROBUX
  converted_amount = 0
  if tocurrency == 'LKR':
    converted_amount = amount * currency_rate[0]

  elif tocurrency == 'USD':
    converted_amount = amount * currency_rate[1]

  elif tocurrency == 'YEN':
    converted_amount = amount * currency_rate[2]

  elif tocurrency == 'RUB':
    converted_amount = amount * currency_rate[3]

  elif tocurrency == 'GDP':
    converted_amount = amount * currency_rate[4]

  elif tocurrency == 'DOGE':
    converted_amount = amount * currency_rate[5]

  elif tocurrency == 'CNY':
    converted_amount = amount * currency_rate[6]

  elif tocurrency == 'ROBUX':
    converted_amount = amount * currency_rate[7]

  elif tocurrency == 'VBUX':
    converted_amount = amount * currency_rate[8]

  elif tocurrency == 'Give me free money':
    print("No")

  return converted_amount


Desision = input("Convert to AUD or Convert from AUD? ")

if Desision == "From AUD":
  tocurrency = input("What currency are you converting to? ")

  amount = input("How much are you converting? ")
  amount = float(amount)


  newamount = conver_currency(tocurrency,amount)
  print(newamount)


elif Desision == ("To AUD"):

  fromcurrency = input("What currency are you converting from? ")

  amount = input("How much are you converting? ")
  amount = float(amount)


  newamounte = convert_currency(fromcurrency,amount)
  print(newamounte)

else: 
  for loop in range(0,10000000000000000000000000000000000000000):
    print("Error 69")
# Out:
# Convert to AUD or Convert from AUD? From AUD
# What currency are you converting to? ROBUX
# How much are you converting? 2000
# 572000.0
